# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset_Facebook.csv")
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
mode=df[["Paid","like","share"]].mode()
mode
# Out:
#    Paid  like  share
# 0   0.0  98.0   13.0
# 1   NaN   NaN   14.0

# %%
df=df.fillna(mode.iloc[0])
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.isna().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
cond1=df[df["Type"]=='Photo']
cond1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
cond2=df[df["Post Month"]>=6]
cond2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 321            123047   Photo         3           6             2         13
# 322            123047   Photo         3           6             2          5
# 323            123047   Photo         3           6             1         10
# 324            123047   Photo         3           6             1          3
# 325            121540   Photo         3           6             1          3
#
# ...

# %%
cond3=df[df["Post Month"]<6]
cond3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 326            121540  Photo         2           5             7         14
# 327            120050  Photo         3           5             5          9
# 328            120050  Photo         3           5             4         12
# 329            120050  Photo         3           5             4          4
# 330            120050  Photo         3           5             3         12
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
cond4=df[(df["Type"]=="Photo") &(df["Category"]==2)]
cond4
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 11             139441  Photo         2          12             5         10
# 12             139441  Photo         2          12             5         10
# ..                ...    ...       ...         ...           ...        ...
# 467             91758  Photo         2           2             5          3
# 480             86909  Photo         2           1             4         11
# 483             86491  Photo         2           1             3          3
# 496             81370  Photo         2           1             5          8
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
cond5=df.head(100)
cond5
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# ..               ...     ...       ...         ...           ...        ...
# 95            137059   Photo         3          10             6         10
# 96            137059   Photo         1          10             6          3
# 97            137059   Photo         2          10             5         11
# 98            137020  Status         2          10             5          3
# 99            137020   Photo         1          10             4         10
#
# ...

# %%
cond6=df.tail(100)
cond6
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 400            107907  Photo         3           4             4          5
# 401            107907  Photo         1           4             3         13
# 402            107907  Photo         1           4             3          4
# 403            107907   Link         1           4             2          6
# 404            107907  Photo         3           4             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
cond7=df[0:500:5]
cond7
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 5              139441  Status         2          12             1          9
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 20             138414   Photo         2          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 475             86909   Photo         3           1             6         16
# 480             86909   Photo         2           1             4         11
# 485             86491    Link         1           1             2          2
# 490             85979   Photo         3           1             6         11
# 495             85093   Photo         3           1             7          2
#
# ...

# %%
cond8=df.iloc[0:300,3:7]
cond8
# Out:
#      Post Month  Post Weekday  Post Hour  Paid
# 0            12             4          3   0.0
# 1            12             3         10   0.0
# 2            12             3          3   0.0
# 3            12             2         10   1.0
# 4            12             2          3   0.0
# ..          ...           ...        ...   ...
# 295           6             2          2   0.0
# 296           6             1         14   0.0
# 297           6             1          3   0.0
# 298           6             7         11   0.0
# 299           6             7          4   0.0
#
# [300 rows x 4 columns]

# %%
cond9=df[["Type","Category","Post Month","Post Weekday","Post Hour"]]
cond9
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour
# 0     Photo         2          12             4          3
# 1    Status         2          12             3         10
# 2     Photo         3          12             3          3
# 3     Photo         2          12             2         10
# 4     Photo         2          12             2          3
# ..      ...       ...         ...           ...        ...
# 495   Photo         3           1             7          2
# 496   Photo         2           1             5          8
# 497   Photo         1           1             5          2
# 498   Photo         3           1             4         11
# 499   Photo         2           1             4          4
#
# [500 rows x 5 columns]

# %%
cond10=df[["Type","comment","like","share"]]
cond10
# Out:
#        Type  comment    like  share
# 0     Photo        4    79.0   17.0
# 1    Status        5   130.0   29.0
# 2     Photo        0    66.0   14.0
# 3     Photo       58  1572.0  147.0
# 4     Photo       19   325.0   49.0
# ..      ...      ...     ...    ...
# 495   Photo        5    53.0   26.0
# 496   Photo        0    53.0   22.0
# 497   Photo        4    93.0   18.0
# 498   Photo        7    91.0   38.0
# 499   Photo        0    91.0   28.0
#
# [500 rows x 4 columns]

# %%
cond11=pd.concat([cond5,cond6],axis=0)
cond11
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
cond15=pd.concat([cond9,cond10],axis=1)
cond15
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour    Type  comment  \
# 0     Photo         2          12             4          3   Photo        4
# 1    Status         2          12             3         10  Status        5
# 2     Photo         3          12             3          3   Photo        0
# 3     Photo         2          12             2         10   Photo       58
# 4     Photo         2          12             2          3   Photo       19
# ..      ...       ...         ...           ...        ...     ...      ...
# 495   Photo         3           1             7          2   Photo        5
# 496   Photo         2           1             5          8   Photo        0
# 497   Photo         1           1             5          2   Photo        4
# 498   Photo         3           1             4         11   Photo        7
# 499   Photo         2           1             4          4   Photo        0
#
#        like  share
# 0      79.0   17.0
# ...

# %%
cond12=cond9.merge(cond10,on="Type")
cond12
# Out:
#          Type  Category  Post Month  Post Weekday  Post Hour  comment    like  \
# 0       Photo         2          12             4          3        4    79.0
# 1       Photo         2          12             4          3        0    66.0
# 2       Photo         2          12             4          3       58  1572.0
# 3       Photo         2          12             4          3       19   325.0
# 4       Photo         2          12             4          3        3   249.0
# ...       ...       ...         ...           ...        ...      ...     ...
# 184029  Photo         2           1             4          4        5    53.0
# 184030  Photo         2           1             4          4        0    53.0
# 184031  Photo         2           1             4          4        4    93.0
# 184032  Photo         2           1             4          4        7    91.0
# 184033  Photo         2           1             4          4        0    91.0
#
#         share
# 0        17.0
# ...

# %%
cond13=df.T
cond13
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# 1    215
# 3    155
# 2    130
# Name: count, dtype: int64

# %%
cond14 = df.groupby(["Paid", "like", "share"]).agg("sum")
cond14
# Out:
#                    Page total likes             Type  Category  Post Month  \
# Paid like   share
# 0.0  0.0    0.0              380377  PhotoPhotoPhoto         3          26
#      1.0    2.0              136393            Photo         1          10
#      2.0    0.0              202844       PhotoPhoto         2           6
#             13.0             136393            Photo         1          10
#      3.0    0.0              237125       PhotoPhoto         2          13
# ...                             ...              ...       ...         ...
# 1.0  859.0  90.0             136013           Status         2          10
#      1047.0 98.0             135195            Photo         3           9
#      1572.0 147.0            139441            Photo         2          12
#      1998.0 128.0            111620            Photo         3           4
#      5172.0 790.0            130791            Photo         2           7
#
# ...
